# %%
# Spring 2022, IOC 5259 Reinforcement Learning
# HW1-partII: REINFORCE and baseline

import gym
from itertools import count
from collections import namedtuple
import numpy as np
from numpy import sqrt 

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical
import torch.optim.lr_scheduler as Scheduler


# Define a useful tuple (optional)
SavedAction = namedtuple('SavedAction', ['log_prob', 'value'])

        
class Policy(nn.Module):
    """
        Implement both policy network and the value network in one model
        - Note that here we let the actor and value networks share the first layer
        - Feel free to change the architecture (e.g. number of hidden layers and the width of each hidden layer) as you like
        - Feel free to add any member variables/functions whenever needed
        TODO:
            1. Initialize the network (including the shared layer(s), the action layer(s), and the value layer(s)
            2. Random weight initialization of each layer
    """
    def __init__(self):
        super(Policy, self).__init__()
        
        # Extract the dimensionality of state and action spaces
        self.discrete = isinstance(env.action_space, gym.spaces.Discrete)
        self.observation_dim = env.observation_space.shape[0]
        self.action_dim = env.action_space.n if self.discrete else env.action_space.shape[0]
        self.hidden_size = 128
#         print(self.observation_dim )
#         print(self.action_dim )
        ########## YOUR CODE HERE (5~10 lines) ##########
        self.s_layer1= nn.Linear(4, self.hidden_size)
        torch.nn.init.xavier_uniform_(self.s_layer1.weight)
                
        self.s_layer2 = nn.Linear(self.hidden_size, self.hidden_size)
        torch.nn.init.xavier_uniform_(self.s_layer2.weight)
        
        self.a_layer = nn.Linear(self.hidden_size, 2)
        torch.nn.init.xavier_uniform_(self.a_layer.weight)

        
        self.v_layer = nn.Linear(self.hidden_size, 1)
        torch.nn.init.xavier_uniform_(self.v_layer.weight)

        ########## END OF YOUR CODE ##########
        
        # action & reward memory
        self.saved_actions = []
        self.rewards = []

    def forward(self, state):
        """
            Forward pass of both policy and value networks
            - The input is the state, and the outputs are the corresponding 
              action probability distirbution and the state value
            TODO:
                1. Implement the forward pass for both the action and the state value
        """
        
        ########## YOUR CODE HERE (3~5 lines) ##########
        x =  self.s_layer1(state)
        x = F.relu(x)
        x =  self.s_layer2(x)
        x = F.relu(x)
        y=self.a_layer(x)
        action_prob = F.softmax(y, dim=-1)  #choses what action you want to take and return probability of each action
        state_value = self.v_layer(x)
         
        # return values are  tuple, action_prob:  the probability of each action over the action space
                                          #  state_value: the value from state s_t 

        ########## END OF YOUR CODE ##########

        return action_prob, state_value




    def select_action(self, state):
        """
            Select the action given the current state
            - The input is the state, and the output is the action to apply 
            (based on the learned stochastic policy)
            TODO:
                1. Implement the forward pass for both the action and the state value
        """
        
        ########## YOUR CODE HERE (3~5 lines) ##########
        state = torch.from_numpy(state).float().squeeze(0)
        action_prob, state_value = self.forward(state)
        m = Categorical(action_prob)  #create a distribution from action_prob
        action = m.sample()    #sample the action

        ########## END OF YOUR CODE ##########
        
        # save to action buffer
        self.saved_actions.append(SavedAction(m.log_prob(action), state_value))

        return action.item()    


    def calculate_loss(self, gamma=0.99):
        """
            Calculate the loss (= policy loss + value loss) to perform backprop later
            TODO:
                1. Calculate rewards-to-go required by REINFORCE with the help of self.rewards
                2. Calculate the policy loss using the policy gradient
                3. Calculate the value loss using either MSE loss or smooth L1 loss
        """
        
        # Initialize the lists and variables
        R = 0
        saved_actions = self.saved_actions
        policy_losses = [] 
        value_losses = [] 
        returns = []

        ########## YOUR CODE HERE (8-15 lines) ##########
        eps = np.finfo(np.float32).eps.item()

        for r in reversed(self.rewards):              # calculate discounted value
            R = r + gamma * R
            returns.insert(0, R)
        
        returns = torch.tensor(returns)
        returns = (returns - returns.mean()) / (returns.std() + eps)  #standardlization for faster converge / eps: To increase the stability when calculating
        
        
        for (log_prob, state_value),R in zip(saved_actions , returns):
            policy_losses.append(R* -log_prob )
            
            value_losses.append( F.mse_loss(state_value, torch.tensor ([R]) ) ) # calcilate loss using MSE
            
        loss = torch.stack(policy_losses).sum()+torch.stack(value_losses).sum()  #sum up both policy_losses and value_losses

        ########## END OF YOUR CODE ##########
        
        return loss

    def clear_memory(self):
        # reset rewards and action buffer
        del self.rewards[:]
        del self.saved_actions[:]


def train(lr=0.01):
    '''
        Train the model using SGD (via backpropagation)
        TODO: In each episode, 
        1. run the policy till the end of the episode and keep the sampled trajectory
        2. update both the policy and the value network at the end of episode
    '''    
    
    # Instantiate the policy model and the optimizer
    model = Policy()
    optimizer = optim.Adam(model.parameters(), lr=lr)
    
    # Learning rate scheduler (optional)
    scheduler = Scheduler.StepLR(optimizer, step_size=100, gamma=0.9)
    
    # EWMA reward for tracking the learning progress
    ewma_reward = 0
    
    # run inifinitely many episodes
    for i_episode in count(1):
        # reset environment and episode reward
        state = env.reset()
        ep_reward = 0
        t = 0
        # Uncomment the following line to use learning rate scheduler
        #scheduler.step()
        
        # For each episode, only run 9999 steps so that we don't 
        # infinite loop while learning
        
        ########## YOUR CODE HERE (10-15 lines) ##########
        for t in range(1, 10000):  # Don't infinite loop while learning
            action = model.select_action(state)       # select action
            s_state, reward, done, _ = env.step(action)

            model.rewards.append(reward)
            ep_reward += reward
            if done:
                break
            state = s_state

        # Backpropagation
        optimizer.zero_grad()     # to reset gradients
        policy_loss = model.calculate_loss()
        policy_loss.backward()
        optimizer.step()
        model.clear_memory()
        
        ########## END OF YOUR CODE ##########
            
        # update EWMA reward and log the results
        ewma_reward = 0.05 * ep_reward + (1 - 0.05) * ewma_reward
        print('Episode {}\tlength: {}\treward: {}\t ewma reward: {}'.format(i_episode, t, ep_reward, ewma_reward))

        # check if we have "solved" the cart pole problem
        if ewma_reward > env.spec.reward_threshold:
            torch.save(model.state_dict(), './preTrained/CartPole_{}.pth'.format(lr))
            print("Solved! Running reward is now {} and "
                  "the last episode runs to {} time steps!".format(ewma_reward, t))
            break


def test(name, n_episodes=10):
    '''
        Test the learned model (no change needed)
    '''      
    model = Policy()
    
    model.load_state_dict(torch.load('./preTrained/{}'.format(name)))
    
    render = True
    max_episode_len = 10000
    
    for i_episode in range(1, n_episodes+1):
        state = env.reset()
        running_reward = 0
        for t in range(max_episode_len+1):
            action = model.select_action(state)
            state, reward, done, _ = env.step(action)
            running_reward += reward
            if render:
                 env.render()
            if done:
                break
        print('Episode {}\tReward: {}'.format(i_episode, running_reward))
    env.close()
    

if __name__ == '__main__':
    # For reproducibility, fix the random seed
    random_seed = 20  
    lr = 0.01
    env = gym.make("CartPole-v0")
    env.seed(random_seed)  
    torch.manual_seed(random_seed)  
    train(lr)
    test('CartPole_0.01.pth')
# Out:
# /Users/claire/anaconda3/lib/python3.9/site-packages/gym/envs/registration.py:505: UserWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1` with the environment ID `CartPole-v1`.
#   logger.warn(
# Episode 1	length: 10	reward: 10.0	 ewma reward: 0.5
# Episode 2	length: 10	reward: 10.0	 ewma reward: 0.975
# Episode 3	length: 30	reward: 30.0	 ewma reward: 2.42625
# Episode 4	length: 14	reward: 14.0	 ewma reward: 3.0049375
# Episode 5	length: 9	reward: 9.0	 ewma reward: 3.304690625
# Episode 6	length: 14	reward: 14.0	 ewma reward: 3.83945609375
# Episode 7	length: 15	reward: 15.0	 ewma reward: 4.3974832890624995
# Episode 8	length: 11	reward: 11.0	 ewma reward: 4.7276091246093745
# Episode 9	length: 14	reward: 14.0	 ewma reward: 5.191228668378906
# Episode 10	length: 14	reward: 14.0	 ewma reward: 5.63166723495996
# Episode 11	length: 19	reward: 19.0	 ewma reward: 6.300083873211962
# Episode 12	length: 23	reward: 23.0	 ewma reward: 7.135079679551364
# Episode 13	length: 19	reward: 19.0	 ewma reward: 7.728325695573796
# Episode 14	length: 22	reward: 22.0	 ewma reward: 8.441909410795105
# Episode 15	length: 31	reward: 31.0	 ewma reward: 9.56981394025535
# Episode 16	length: 22	reward: 22.0	 ewma reward: 10.191323243242582
# Episode 17	length: 22	reward: 22.0	 ewma reward: 10.781757081080451
# Episode 18	length: 26	reward: 26.0	 ewma reward: 11.54266922702643
# Episode 19	length: 15	reward: 15.0	 ewma reward: 11.715535765675108
# Episode 20	length: 14	reward: 14.0	 ewma reward: 11.829758977391352
# Episode 21	length: 12	reward: 12.0	 ewma reward: 11.838271028521783
# Episode 22	length: 13	reward: 13.0	 ewma reward: 11.896357477095693
# Episode 23	length: 14	reward: 14.0	 ewma reward: 12.001539603240907
# Episode 24	length: 14	reward: 14.0	 ewma reward: 12.101462623078861
# Episode 25	length: 21	reward: 21.0	 ewma reward: 12.546389491924918
# Episode 26	length: 26	reward: 26.0	 ewma reward: 13.219070017328672
# Episode 27	length: 25	reward: 25.0	 ewma reward: 13.808116516462238
# Episode 28	length: 28	reward: 28.0	 ewma reward: 14.517710690639126
# Episode 29	length: 15	reward: 15.0	 ewma reward: 14.54182515610717
# Episode 30	length: 25	reward: 25.0	 ewma reward: 15.06473389830181
# Episode 31	length: 64	reward: 64.0	 ewma reward: 17.511497203386718
# Episode 32	length: 26	reward: 26.0	 ewma reward: 17.93592234321738
# Episode 33	length: 27	reward: 27.0	 ewma reward: 18.38912622605651
# Episode 34	length: 22	reward: 22.0	 ewma reward: 18.569669914753685
# Episode 35	length: 109	reward: 109.0	 ewma reward: 23.091186419016
# Episode 36	length: 18	reward: 18.0	 ewma reward: 22.836627098065197
# Episode 37	length: 22	reward: 22.0	 ewma reward: 22.794795743161938
# Episode 38	length: 41	reward: 41.0	 ewma reward: 23.70505595600384
# Episode 39	length: 13	reward: 13.0	 ewma reward: 23.169803158203646
# Episode 40	length: 21	reward: 21.0	 ewma reward: 23.061313000293463
# Episode 41	length: 36	reward: 36.0	 ewma reward: 23.70824735027879
# Episode 42	length: 22	reward: 22.0	 ewma reward: 23.62283498276485
# Episode 43	length: 22	reward: 22.0	 ewma reward: 23.541693233626606
# Episode 44	length: 18	reward: 18.0	 ewma reward: 23.264608571945274
# Episode 45	length: 58	reward: 58.0	 ewma reward: 25.001378143348013
# Episode 46	length: 27	reward: 27.0	 ewma reward: 25.10130923618061
# Episode 47	length: 20	reward: 20.0	 ewma reward: 24.84624377437158
# Episode 48	length: 27	reward: 27.0	 ewma reward: 24.953931585653002
# Episode 49	length: 23	reward: 23.0	 ewma reward: 24.85623500637035
# Episode 50	length: 24	reward: 24.0	 ewma reward: 24.81342325605183
# Episode 51	length: 30	reward: 30.0	 ewma reward: 25.07275209324924
# Episode 52	length: 23	reward: 23.0	 ewma reward: 24.969114488586776
# Episode 53	length: 49	reward: 49.0	 ewma reward: 26.170658764157434
# Episode 54	length: 44	reward: 44.0	 ewma reward: 27.06212582594956
# Episode 55	length: 60	reward: 60.0	 ewma reward: 28.709019534652082
# Episode 56	length: 13	reward: 13.0	 ewma reward: 27.923568557919474
# Episode 57	length: 97	reward: 97.0	 ewma reward: 31.3773901300235
# Episode 58	length: 94	reward: 94.0	 ewma reward: 34.50852062352232
# Episode 59	length: 37	reward: 37.0	 ewma reward: 34.633094592346204
# Episode 60	length: 108	reward: 108.0	 ewma reward: 38.30143986272889
# Episode 61	length: 125	reward: 125.0	 ewma reward: 42.63636786959245
# Episode 62	length: 41	reward: 41.0	 ewma reward: 42.55454947611282
# Episode 63	length: 21	reward: 21.0	 ewma reward: 41.47682200230717
# Episode 64	length: 70	reward: 70.0	 ewma reward: 42.902980902191814
# Episode 65	length: 55	reward: 55.0	 ewma reward: 43.50783185708222
# Episode 66	length: 200	reward: 200.0	 ewma reward: 51.33244026422811
# Episode 67	length: 94	reward: 94.0	 ewma reward: 53.46581825101671
# Episode 68	length: 70	reward: 70.0	 ewma reward: 54.29252733846587
# Episode 69	length: 30	reward: 30.0	 ewma reward: 53.07790097154257
# Episode 70	length: 63	reward: 63.0	 ewma reward: 53.57400592296543
# Episode 71	length: 30	reward: 30.0	 ewma reward: 52.39530562681716
# Episode 72	length: 57	reward: 57.0	 ewma reward: 52.6255403454763
# Episode 73	length: 20	reward: 20.0	 ewma reward: 50.994263328202486
# Episode 74	length: 35	reward: 35.0	 ewma reward: 50.19455016179236
# Episode 75	length: 62	reward: 62.0	 ewma reward: 50.78482265370274
# Episode 76	length: 24	reward: 24.0	 ewma reward: 49.4455815210176
# Episode 77	length: 74	reward: 74.0	 ewma reward: 50.67330244496672
# Episode 78	length: 39	reward: 39.0	 ewma reward: 50.08963732271839
# Episode 79	length: 32	reward: 32.0	 ewma reward: 49.18515545658247
# Episode 80	length: 77	reward: 77.0	 ewma reward: 50.57589768375335
# Episode 81	length: 166	reward: 166.0	 ewma reward: 56.347102799565675
# Episode 82	length: 121	reward: 121.0	 ewma reward: 59.57974765958738
# Episode 83	length: 92	reward: 92.0	 ewma reward: 61.200760276608015
# Episode 84	length: 170	reward: 170.0	 ewma reward: 66.64072226277762
# Episode 85	length: 196	reward: 196.0	 ewma reward: 73.10868614963873
# Episode 86	length: 102	reward: 102.0	 ewma reward: 74.55325184215678
# Episode 87	length: 123	reward: 123.0	 ewma reward: 76.97558925004894
# Episode 88	length: 146	reward: 146.0	 ewma reward: 80.42680978754649
# Episode 89	length: 22	reward: 22.0	 ewma reward: 77.50546929816916
# Episode 90	length: 15	reward: 15.0	 ewma reward: 74.3801958332607
# Episode 91	length: 197	reward: 197.0	 ewma reward: 80.51118604159765
# Episode 92	length: 21	reward: 21.0	 ewma reward: 77.53562673951777
# Episode 93	length: 50	reward: 50.0	 ewma reward: 76.15884540254187
# Episode 94	length: 167	reward: 167.0	 ewma reward: 80.70090313241477
# Episode 95	length: 26	reward: 26.0	 ewma reward: 77.96585797579402
# Episode 96	length: 168	reward: 168.0	 ewma reward: 82.46756507700432
# Episode 97	length: 37	reward: 37.0	 ewma reward: 80.1941868231541
# Episode 98	length: 32	reward: 32.0	 ewma reward: 77.78447748199639
# Episode 99	length: 11	reward: 11.0	 ewma reward: 74.44525360789656
# Episode 100	length: 35	reward: 35.0	 ewma reward: 72.47299092750173
# Episode 101	length: 33	reward: 33.0	 ewma reward: 70.49934138112664
# Episode 102	length: 18	reward: 18.0	 ewma reward: 67.87437431207032
# Episode 103	length: 17	reward: 17.0	 ewma reward: 65.3306555964668
# Episode 104	length: 21	reward: 21.0	 ewma reward: 63.11412281664345
# Episode 105	length: 17	reward: 17.0	 ewma reward: 60.80841667581128
# Episode 106	length: 10	reward: 10.0	 ewma reward: 58.26799584202071
# Episode 107	length: 12	reward: 12.0	 ewma reward: 55.95459604991967
# Episode 108	length: 16	reward: 16.0	 ewma reward: 53.95686624742368
# Episode 109	length: 66	reward: 66.0	 ewma reward: 54.5590229350525
# Episode 110	length: 27	reward: 27.0	 ewma reward: 53.18107178829987
# Episode 111	length: 15	reward: 15.0	 ewma reward: 51.27201819888487
# Episode 112	length: 22	reward: 22.0	 ewma reward: 49.808417288940625
# Episode 113	length: 61	reward: 61.0	 ewma reward: 50.36799642449359
# Episode 114	length: 24	reward: 24.0	 ewma reward: 49.04959660326891
# Episode 115	length: 19	reward: 19.0	 ewma reward: 47.547116773105465
# Episode 116	length: 43	reward: 43.0	 ewma reward: 47.31976093445019
# Episode 117	length: 24	reward: 24.0	 ewma reward: 46.153772887727676
# Episode 118	length: 15	reward: 15.0	 ewma reward: 44.59608424334129
# Episode 119	length: 36	reward: 36.0	 ewma reward: 44.16628003117422
# Episode 120	length: 36	reward: 36.0	 ewma reward: 43.7579660296155
# Episode 121	length: 28	reward: 28.0	 ewma reward: 42.97006772813472
# Episode 122	length: 22	reward: 22.0	 ewma reward: 41.921564341727986
# Episode 123	length: 46	reward: 46.0	 ewma reward: 42.12548612464158
# Episode 124	length: 25	reward: 25.0	 ewma reward: 41.2692118184095
# Episode 125	length: 13	reward: 13.0	 ewma reward: 39.85575122748902
# Episode 126	length: 56	reward: 56.0	 ewma reward: 40.662963666114564
# Episode 127	length: 70	reward: 70.0	 ewma reward: 42.12981548280884
# Episode 128	length: 50	reward: 50.0	 ewma reward: 42.52332470866839
# Episode 129	length: 32	reward: 32.0	 ewma reward: 41.99715847323497
# Episode 130	length: 96	reward: 96.0	 ewma reward: 44.697300549573214
# Episode 131	length: 12	reward: 12.0	 ewma reward: 43.06243552209455
# Episode 132	length: 106	reward: 106.0	 ewma reward: 46.20931374598982
# Episode 133	length: 83	reward: 83.0	 ewma reward: 48.048848058690325
# Episode 134	length: 65	reward: 65.0	 ewma reward: 48.89640565575581
# Episode 135	length: 89	reward: 89.0	 ewma reward: 50.901585372968015
# Episode 136	length: 53	reward: 53.0	 ewma reward: 51.00650610431961
# Episode 137	length: 46	reward: 46.0	 ewma reward: 50.756180799103625
# Episode 138	length: 18	reward: 18.0	 ewma reward: 49.11837175914844
# Episode 139	length: 28	reward: 28.0	 ewma reward: 48.06245317119101
# Episode 140	length: 27	reward: 27.0	 ewma reward: 47.00933051263146
# Episode 141	length: 18	reward: 18.0	 ewma reward: 45.55886398699988
# Episode 142	length: 48	reward: 48.0	 ewma reward: 45.68092078764988
# Episode 143	length: 52	reward: 52.0	 ewma reward: 45.99687474826739
# Episode 144	length: 48	reward: 48.0	 ewma reward: 46.09703101085402
# Episode 145	length: 16	reward: 16.0	 ewma reward: 44.592179460311314
# Episode 146	length: 17	reward: 17.0	 ewma reward: 43.21257048729575
# Episode 147	length: 16	reward: 16.0	 ewma reward: 41.85194196293096
# Episode 148	length: 98	reward: 98.0	 ewma reward: 44.65934486478441
# Episode 149	length: 83	reward: 83.0	 ewma reward: 46.576377621545184
# Episode 150	length: 13	reward: 13.0	 ewma reward: 44.89755874046792
# Episode 151	length: 34	reward: 34.0	 ewma reward: 44.35268080344453
# Episode 152	length: 23	reward: 23.0	 ewma reward: 43.2850467632723
# Episode 153	length: 103	reward: 103.0	 ewma reward: 46.27079442510868
# Episode 154	length: 27	reward: 27.0	 ewma reward: 45.307254703853246
# Episode 155	length: 26	reward: 26.0	 ewma reward: 44.341891968660576
# Episode 156	length: 17	reward: 17.0	 ewma reward: 42.97479737022755
# Episode 157	length: 29	reward: 29.0	 ewma reward: 42.276057501716174
# Episode 158	length: 57	reward: 57.0	 ewma reward: 43.012254626630366
# Episode 159	length: 20	reward: 20.0	 ewma reward: 41.861641895298845
# Episode 160	length: 44	reward: 44.0	 ewma reward: 41.9685598005339
# Episode 161	length: 60	reward: 60.0	 ewma reward: 42.8701318105072
# Episode 162	length: 19	reward: 19.0	 ewma reward: 41.676625219981844
# Episode 248	length: 150	reward: 150.0	 ewma reward: 97.67062811691322
# Episode 249	length: 191	reward: 191.0	 ewma reward: 102.33709671106756
# Episode 250	length: 179	reward: 179.0	 ewma reward: 106.17024187551418
# Episode 251	length: 140	reward: 140.0	 ewma reward: 107.86172978173846
# Episode 252	length: 134	reward: 134.0	 ewma reward: 109.16864329265154
# Episode 253	length: 13	reward: 13.0	 ewma reward: 104.36021112801896
# Episode 254	length: 110	reward: 110.0	 ewma reward: 104.642200571618
# Episode 255	length: 147	reward: 147.0	 ewma reward: 106.7600905430371
# Episode 256	length: 98	reward: 98.0	 ewma reward: 106.32208601588525
# Episode 257	length: 108	reward: 108.0	 ewma reward: 106.40598171509099
# Episode 258	length: 200	reward: 200.0	 ewma reward: 111.08568262933643
# Episode 259	length: 200	reward: 200.0	 ewma reward: 115.5313984978696
# Episode 260	length: 131	reward: 131.0	 ewma reward: 116.30482857297612
# Episode 261	length: 110	reward: 110.0	 ewma reward: 115.9895871443273
# Episode 262	length: 78	reward: 78.0	 ewma reward: 114.09010778711094
# Episode 263	length: 88	reward: 88.0	 ewma reward: 112.7856023977554
# Episode 264	length: 200	reward: 200.0	 ewma reward: 117.14632227786763
# Episode 265	length: 29	reward: 29.0	 ewma reward: 112.73900616397424
# Episode 266	length: 167	reward: 167.0	 ewma reward: 115.45205585577551
# Episode 267	length: 22	reward: 22.0	 ewma reward: 110.77945306298673
# Episode 268	length: 200	reward: 200.0	 ewma reward: 115.24048040983739
# Episode 269	length: 115	reward: 115.0	 ewma reward: 115.22845638934551
# Episode 270	length: 200	reward: 200.0	 ewma reward: 119.46703356987823
# Episode 271	length: 200	reward: 200.0	 ewma reward: 123.49368189138431
# Episode 272	length: 79	reward: 79.0	 ewma reward: 121.2689977968151
# Episode 273	length: 85	reward: 85.0	 ewma reward: 119.45554790697435
# Episode 274	length: 140	reward: 140.0	 ewma reward: 120.48277051162562
# Episode 275	length: 142	reward: 142.0	 ewma reward: 121.55863198604432
# Episode 276	length: 102	reward: 102.0	 ewma reward: 120.5807003867421
# Episode 277	length: 69	reward: 69.0	 ewma reward: 118.00166536740498
# Episode 278	length: 115	reward: 115.0	 ewma reward: 117.85158209903473
# Episode 279	length: 158	reward: 158.0	 ewma reward: 119.859002994083
# Episode 280	length: 124	reward: 124.0	 ewma reward: 120.06605284437885
# Episode 281	length: 200	reward: 200.0	 ewma reward: 124.0627502021599
# Episode 282	length: 200	reward: 200.0	 ewma reward: 127.8596126920519
# Episode 283	length: 200	reward: 200.0	 ewma reward: 131.46663205744932
# Episode 284	length: 92	reward: 92.0	 ewma reward: 129.49330045457685
# Episode 285	length: 200	reward: 200.0	 ewma reward: 133.018635431848
# Episode 286	length: 165	reward: 165.0	 ewma reward: 134.6177036602556
# Episode 287	length: 200	reward: 200.0	 ewma reward: 137.8868184772428
# Episode 288	length: 68	reward: 68.0	 ewma reward: 134.39247755338064
# Episode 289	length: 77	reward: 77.0	 ewma reward: 131.52285367571162
# Episode 290	length: 26	reward: 26.0	 ewma reward: 126.24671099192602
# Episode 291	length: 141	reward: 141.0	 ewma reward: 126.9843754423297
# Episode 292	length: 101	reward: 101.0	 ewma reward: 125.68515667021322
# Episode 293	length: 132	reward: 132.0	 ewma reward: 126.00089883670255
# Episode 294	length: 134	reward: 134.0	 ewma reward: 126.40085389486741
# Episode 295	length: 92	reward: 92.0	 ewma reward: 124.68081120012403
# Episode 296	length: 79	reward: 79.0	 ewma reward: 122.39677064011782
# Episode 297	length: 131	reward: 131.0	 ewma reward: 122.82693210811192
# Episode 298	length: 135	reward: 135.0	 ewma reward: 123.43558550270632
# Episode 299	length: 93	reward: 93.0	 ewma reward: 121.913806227571
# Episode 300	length: 118	reward: 118.0	 ewma reward: 121.71811591619245
# Episode 301	length: 104	reward: 104.0	 ewma reward: 120.83221012038283
# Episode 302	length: 101	reward: 101.0	 ewma reward: 119.84059961436368
# Episode 303	length: 118	reward: 118.0	 ewma reward: 119.7485696336455
# Episode 304	length: 98	reward: 98.0	 ewma reward: 118.66114115196322
# Episode 305	length: 56	reward: 56.0	 ewma reward: 115.52808409436506
# Episode 306	length: 142	reward: 142.0	 ewma reward: 116.85167988964679
# Episode 307	length: 111	reward: 111.0	 ewma reward: 116.55909589516445
# Episode 308	length: 19	reward: 19.0	 ewma reward: 111.68114110040622
# Episode 309	length: 125	reward: 125.0	 ewma reward: 112.34708404538591
# Episode 310	length: 58	reward: 58.0	 ewma reward: 109.62972984311662
# Episode 311	length: 32	reward: 32.0	 ewma reward: 105.74824335096078
# Episode 312	length: 21	reward: 21.0	 ewma reward: 101.51083118341273
# Episode 313	length: 32	reward: 32.0	 ewma reward: 98.03528962424208
# Episode 314	length: 126	reward: 126.0	 ewma reward: 99.43352514302997
# Episode 315	length: 81	reward: 81.0	 ewma reward: 98.51184888587846
# Episode 316	length: 136	reward: 136.0	 ewma reward: 100.38625644158454
# Episode 317	length: 158	reward: 158.0	 ewma reward: 103.26694361950531
# Episode 318	length: 114	reward: 114.0	 ewma reward: 103.80359643853005
# Episode 319	length: 129	reward: 129.0	 ewma reward: 105.06341661660355
# Episode 320	length: 100	reward: 100.0	 ewma reward: 104.81024578577336
# Episode 321	length: 200	reward: 200.0	 ewma reward: 109.56973349648469
# Episode 322	length: 200	reward: 200.0	 ewma reward: 114.09124682166045
# Episode 323	length: 200	reward: 200.0	 ewma reward: 118.38668448057742
# Episode 324	length: 200	reward: 200.0	 ewma reward: 122.46735025654854
# Episode 325	length: 23	reward: 23.0	 ewma reward: 117.49398274372112
# Episode 326	length: 200	reward: 200.0	 ewma reward: 121.61928360653506
# Episode 327	length: 200	reward: 200.0	 ewma reward: 125.5383194262083
# Episode 328	length: 200	reward: 200.0	 ewma reward: 129.2614034548979
# Episode 329	length: 143	reward: 143.0	 ewma reward: 129.948333282153
# Episode 330	length: 200	reward: 200.0	 ewma reward: 133.4509166180453
# Episode 331	length: 200	reward: 200.0	 ewma reward: 136.77837078714305
# Episode 332	length: 200	reward: 200.0	 ewma reward: 139.93945224778588
# Episode 333	length: 200	reward: 200.0	 ewma reward: 142.94247963539658
# Episode 334	length: 200	reward: 200.0	 ewma reward: 145.79535565362676
# Episode 335	length: 150	reward: 150.0	 ewma reward: 146.00558787094542
# Episode 336	length: 200	reward: 200.0	 ewma reward: 148.70530847739815
# Episode 337	length: 163	reward: 163.0	 ewma reward: 149.42004305352825
# Episode 338	length: 187	reward: 187.0	 ewma reward: 151.29904090085182
# Episode 339	length: 130	reward: 130.0	 ewma reward: 150.23408885580923
# Episode 340	length: 164	reward: 164.0	 ewma reward: 150.92238441301876
# Episode 341	length: 147	reward: 147.0	 ewma reward: 150.7262651923678
# Episode 342	length: 166	reward: 166.0	 ewma reward: 151.48995193274942
# Episode 343	length: 200	reward: 200.0	 ewma reward: 153.91545433611194
# Episode 344	length: 22	reward: 22.0	 ewma reward: 147.31968161930632
# Episode 345	length: 194	reward: 194.0	 ewma reward: 149.653697538341
# Episode 346	length: 16	reward: 16.0	 ewma reward: 142.97101266142394
# Episode 347	length: 200	reward: 200.0	 ewma reward: 145.82246202835273
# Episode 348	length: 200	reward: 200.0	 ewma reward: 148.5313389269351
# Episode 349	length: 190	reward: 190.0	 ewma reward: 150.60477198058834
# Episode 350	length: 32	reward: 32.0	 ewma reward: 144.67453338155892
# Episode 351	length: 200	reward: 200.0	 ewma reward: 147.44080671248096
# Episode 352	length: 162	reward: 162.0	 ewma reward: 148.1687663768569
# Episode 353	length: 151	reward: 151.0	 ewma reward: 148.31032805801405
# Episode 354	length: 72	reward: 72.0	 ewma reward: 144.49481165511332
# Episode 355	length: 200	reward: 200.0	 ewma reward: 147.27007107235764
# Episode 356	length: 200	reward: 200.0	 ewma reward: 149.90656751873976
# Episode 357	length: 200	reward: 200.0	 ewma reward: 152.41123914280277
# Episode 358	length: 200	reward: 200.0	 ewma reward: 154.79067718566262
# Episode 359	length: 200	reward: 200.0	 ewma reward: 157.05114332637947
# Episode 360	length: 200	reward: 200.0	 ewma reward: 159.1985861600605
# Episode 361	length: 167	reward: 167.0	 ewma reward: 159.58865685205745
# Episode 362	length: 200	reward: 200.0	 ewma reward: 161.60922400945458
# Episode 363	length: 200	reward: 200.0	 ewma reward: 163.52876280898184
# Episode 364	length: 200	reward: 200.0	 ewma reward: 165.35232466853273
# Episode 365	length: 200	reward: 200.0	 ewma reward: 167.08470843510608
# Episode 366	length: 165	reward: 165.0	 ewma reward: 166.98047301335077
# Episode 367	length: 160	reward: 160.0	 ewma reward: 166.63144936268324
# Episode 368	length: 200	reward: 200.0	 ewma reward: 168.29987689454907
# Episode 369	length: 167	reward: 167.0	 ewma reward: 168.2348830498216
# Episode 370	length: 127	reward: 127.0	 ewma reward: 166.17313889733052
# Episode 371	length: 169	reward: 169.0	 ewma reward: 166.31448195246398
# Episode 372	length: 100	reward: 100.0	 ewma reward: 162.99875785484076
# Episode 373	length: 55	reward: 55.0	 ewma reward: 157.5988199620987
# Episode 374	length: 126	reward: 126.0	 ewma reward: 156.01887896399379
# Episode 375	length: 133	reward: 133.0	 ewma reward: 154.8679350157941
# Episode 376	length: 185	reward: 185.0	 ewma reward: 156.3745382650044
# Episode 377	length: 155	reward: 155.0	 ewma reward: 156.30581135175416
# Episode 378	length: 112	reward: 112.0	 ewma reward: 154.09052078416644
# Episode 379	length: 54	reward: 54.0	 ewma reward: 149.0859947449581
# Episode 380	length: 131	reward: 131.0	 ewma reward: 148.1816950077102
# Episode 381	length: 39	reward: 39.0	 ewma reward: 142.72261025732467
# Episode 382	length: 78	reward: 78.0	 ewma reward: 139.48647974445845
# Episode 383	length: 200	reward: 200.0	 ewma reward: 142.51215575723552
# Episode 384	length: 169	reward: 169.0	 ewma reward: 143.83654796937373
# Episode 385	length: 85	reward: 85.0	 ewma reward: 140.89472057090504
# Episode 386	length: 125	reward: 125.0	 ewma reward: 140.09998454235978
# Episode 387	length: 200	reward: 200.0	 ewma reward: 143.0949853152418
# Episode 388	length: 71	reward: 71.0	 ewma reward: 139.4902360494797
# Episode 389	length: 106	reward: 106.0	 ewma reward: 137.81572424700573
# Episode 390	length: 200	reward: 200.0	 ewma reward: 140.92493803465544
# Episode 391	length: 200	reward: 200.0	 ewma reward: 143.87869113292265
# Episode 392	length: 200	reward: 200.0	 ewma reward: 146.68475657627653
# Episode 393	length: 72	reward: 72.0	 ewma reward: 142.9505187474627
# Episode 394	length: 105	reward: 105.0	 ewma reward: 141.05299281008956
# Episode 395	length: 200	reward: 200.0	 ewma reward: 144.00034316958508
# Episode 396	length: 200	reward: 200.0	 ewma reward: 146.80032601110582
# Episode 397	length: 117	reward: 117.0	 ewma reward: 145.3103097105505
# Episode 398	length: 200	reward: 200.0	 ewma reward: 148.04479422502297
# Episode 399	length: 200	reward: 200.0	 ewma reward: 150.6425545137718
# Episode 400	length: 200	reward: 200.0	 ewma reward: 153.1104267880832
# Episode 401	length: 200	reward: 200.0	 ewma reward: 155.45490544867903
# Episode 402	length: 132	reward: 132.0	 ewma reward: 154.28216017624507
# Episode 403	length: 66	reward: 66.0	 ewma reward: 149.86805216743284
# Episode 404	length: 200	reward: 200.0	 ewma reward: 152.3746495590612
# Episode 405	length: 90	reward: 90.0	 ewma reward: 149.25591708110812
# Episode 406	length: 200	reward: 200.0	 ewma reward: 151.79312122705272
# Episode 407	length: 200	reward: 200.0	 ewma reward: 154.20346516570007
# Episode 408	length: 135	reward: 135.0	 ewma reward: 153.24329190741506
# Episode 409	length: 200	reward: 200.0	 ewma reward: 155.5811273120443
# Episode 410	length: 200	reward: 200.0	 ewma reward: 157.80207094644206
# Episode 411	length: 173	reward: 173.0	 ewma reward: 158.56196739911996
# Episode 412	length: 37	reward: 37.0	 ewma reward: 152.48386902916394
# Episode 413	length: 51	reward: 51.0	 ewma reward: 147.40967557770574
# Episode 414	length: 98	reward: 98.0	 ewma reward: 144.93919179882045
# Episode 415	length: 15	reward: 15.0	 ewma reward: 138.4422322088794
# Episode 416	length: 23	reward: 23.0	 ewma reward: 132.67012059843543
# Episode 501	length: 76	reward: 76.0	 ewma reward: 91.03332650179415
# Episode 502	length: 64	reward: 64.0	 ewma reward: 89.68166017670444
# Episode 503	length: 90	reward: 90.0	 ewma reward: 89.69757716786921
# Episode 504	length: 23	reward: 23.0	 ewma reward: 86.36269830947576
# Episode 505	length: 113	reward: 113.0	 ewma reward: 87.69456339400197
# Episode 506	length: 86	reward: 86.0	 ewma reward: 87.60983522430188
# Episode 507	length: 138	reward: 138.0	 ewma reward: 90.12934346308678
# Episode 508	length: 26	reward: 26.0	 ewma reward: 86.92287628993243
# Episode 509	length: 101	reward: 101.0	 ewma reward: 87.6267324754358
# Episode 510	length: 145	reward: 145.0	 ewma reward: 90.49539585166401
# Episode 511	length: 192	reward: 192.0	 ewma reward: 95.57062605908081
# Episode 512	length: 200	reward: 200.0	 ewma reward: 100.79209475612676
# Episode 513	length: 200	reward: 200.0	 ewma reward: 105.75249001832042
# Episode 514	length: 200	reward: 200.0	 ewma reward: 110.46486551740439
# Episode 515	length: 200	reward: 200.0	 ewma reward: 114.94162224153416
# Episode 516	length: 49	reward: 49.0	 ewma reward: 111.64454112945745
# Episode 517	length: 200	reward: 200.0	 ewma reward: 116.06231407298458
# Episode 518	length: 200	reward: 200.0	 ewma reward: 120.25919836933534
# Episode 519	length: 200	reward: 200.0	 ewma reward: 124.24623845086856
# Episode 520	length: 200	reward: 200.0	 ewma reward: 128.03392652832514
# Episode 521	length: 200	reward: 200.0	 ewma reward: 131.6322302019089
# Episode 522	length: 200	reward: 200.0	 ewma reward: 135.05061869181344
# Episode 523	length: 200	reward: 200.0	 ewma reward: 138.29808775722276
# Episode 524	length: 200	reward: 200.0	 ewma reward: 141.3831833693616
# Episode 525	length: 200	reward: 200.0	 ewma reward: 144.31402420089353
# Episode 526	length: 200	reward: 200.0	 ewma reward: 147.09832299084886
# Episode 527	length: 200	reward: 200.0	 ewma reward: 149.7434068413064
# Episode 528	length: 200	reward: 200.0	 ewma reward: 152.25623649924108
# Episode 529	length: 200	reward: 200.0	 ewma reward: 154.64342467427903
# Episode 530	length: 200	reward: 200.0	 ewma reward: 156.91125344056508
# Episode 531	length: 200	reward: 200.0	 ewma reward: 159.06569076853683
# Episode 532	length: 200	reward: 200.0	 ewma reward: 161.11240623010997
# Episode 533	length: 200	reward: 200.0	 ewma reward: 163.05678591860448
# Episode 534	length: 200	reward: 200.0	 ewma reward: 164.90394662267425
# Episode 535	length: 200	reward: 200.0	 ewma reward: 166.65874929154054
# Episode 536	length: 200	reward: 200.0	 ewma reward: 168.3258118269635
# Episode 537	length: 200	reward: 200.0	 ewma reward: 169.90952123561533
# Episode 538	length: 200	reward: 200.0	 ewma reward: 171.41404517383455
# Episode 539	length: 200	reward: 200.0	 ewma reward: 172.8433429151428
# Episode 540	length: 200	reward: 200.0	 ewma reward: 174.20117576938566
# Episode 541	length: 200	reward: 200.0	 ewma reward: 175.49111698091636
# Episode 542	length: 200	reward: 200.0	 ewma reward: 176.71656113187052
# Episode 543	length: 200	reward: 200.0	 ewma reward: 177.880733075277
# Episode 544	length: 200	reward: 200.0	 ewma reward: 178.98669642151313
# Episode 545	length: 200	reward: 200.0	 ewma reward: 180.03736160043746
# Episode 546	length: 200	reward: 200.0	 ewma reward: 181.03549352041557
# Episode 547	length: 200	reward: 200.0	 ewma reward: 181.9837188443948
# Episode 548	length: 200	reward: 200.0	 ewma reward: 182.88453290217504
# Episode 549	length: 200	reward: 200.0	 ewma reward: 183.74030625706627
# Episode 550	length: 134	reward: 134.0	 ewma reward: 181.25329094421292
# Episode 551	length: 64	reward: 64.0	 ewma reward: 175.39062639700225
# Episode 552	length: 71	reward: 71.0	 ewma reward: 170.17109507715213
# Episode 553	length: 200	reward: 200.0	 ewma reward: 171.6625403232945
# Episode 554	length: 72	reward: 72.0	 ewma reward: 166.67941330712978
# Episode 555	length: 92	reward: 92.0	 ewma reward: 162.94544264177327
# Episode 556	length: 200	reward: 200.0	 ewma reward: 164.7981705096846
# Episode 557	length: 87	reward: 87.0	 ewma reward: 160.90826198420038
# Episode 558	length: 94	reward: 94.0	 ewma reward: 157.56284888499033
# Episode 559	length: 97	reward: 97.0	 ewma reward: 154.5347064407408
# Episode 560	length: 200	reward: 200.0	 ewma reward: 156.80797111870373
# Episode 561	length: 83	reward: 83.0	 ewma reward: 153.11757256276854
# Episode 562	length: 102	reward: 102.0	 ewma reward: 150.5616939346301
# Episode 563	length: 106	reward: 106.0	 ewma reward: 148.3336092378986
# Episode 564	length: 26	reward: 26.0	 ewma reward: 142.21692877600367
# Episode 565	length: 98	reward: 98.0	 ewma reward: 140.00608233720348
# Episode 566	length: 67	reward: 67.0	 ewma reward: 136.3557782203433
# Episode 567	length: 83	reward: 83.0	 ewma reward: 133.68798930932613
# Episode 568	length: 98	reward: 98.0	 ewma reward: 131.9035898438598
# Episode 569	length: 108	reward: 108.0	 ewma reward: 130.7084103516668
# Episode 570	length: 103	reward: 103.0	 ewma reward: 129.32298983408344
# Episode 571	length: 102	reward: 102.0	 ewma reward: 127.95684034237927
# Episode 572	length: 98	reward: 98.0	 ewma reward: 126.4589983252603
# Episode 573	length: 104	reward: 104.0	 ewma reward: 125.33604840899729
# Episode 574	length: 104	reward: 104.0	 ewma reward: 124.26924598854742
# Episode 575	length: 32	reward: 32.0	 ewma reward: 119.65578368912004
# Episode 576	length: 22	reward: 22.0	 ewma reward: 114.77299450466403
# Episode 577	length: 111	reward: 111.0	 ewma reward: 114.58434477943082
# Episode 578	length: 89	reward: 89.0	 ewma reward: 113.30512754045928
# Episode 579	length: 121	reward: 121.0	 ewma reward: 113.68987116343631
# Episode 580	length: 100	reward: 100.0	 ewma reward: 113.00537760526448
# Episode 581	length: 200	reward: 200.0	 ewma reward: 117.35510872500126
# Episode 582	length: 101	reward: 101.0	 ewma reward: 116.53735328875119
# Episode 583	length: 200	reward: 200.0	 ewma reward: 120.71048562431362
# Episode 584	length: 119	reward: 119.0	 ewma reward: 120.62496134309794
# Episode 585	length: 112	reward: 112.0	 ewma reward: 120.19371327594303
# Episode 586	length: 126	reward: 126.0	 ewma reward: 120.48402761214587
# Episode 587	length: 200	reward: 200.0	 ewma reward: 124.45982623153857
# Episode 588	length: 143	reward: 143.0	 ewma reward: 125.38683491996164
# Episode 589	length: 127	reward: 127.0	 ewma reward: 125.46749317396355
# Episode 590	length: 120	reward: 120.0	 ewma reward: 125.19411851526536
# Episode 591	length: 200	reward: 200.0	 ewma reward: 128.93441258950207
# Episode 592	length: 159	reward: 159.0	 ewma reward: 130.43769196002697
# Episode 593	length: 200	reward: 200.0	 ewma reward: 133.91580736202562
# Episode 594	length: 151	reward: 151.0	 ewma reward: 134.77001699392434
# Episode 595	length: 131	reward: 131.0	 ewma reward: 134.58151614422812
# Episode 596	length: 86	reward: 86.0	 ewma reward: 132.1524403370167
# Episode 597	length: 200	reward: 200.0	 ewma reward: 135.54481832016586
# Episode 598	length: 200	reward: 200.0	 ewma reward: 138.76757740415755
# Episode 599	length: 200	reward: 200.0	 ewma reward: 141.82919853394966
# Episode 600	length: 21	reward: 21.0	 ewma reward: 135.78773860725218
# Episode 601	length: 22	reward: 22.0	 ewma reward: 130.09835167688956
# Episode 602	length: 126	reward: 126.0	 ewma reward: 129.89343409304507
# Episode 603	length: 112	reward: 112.0	 ewma reward: 128.9987623883928
# Episode 604	length: 120	reward: 120.0	 ewma reward: 128.54882426897316
# Episode 605	length: 100	reward: 100.0	 ewma reward: 127.1213830555245
# Episode 606	length: 29	reward: 29.0	 ewma reward: 122.21531390274828
# Episode 607	length: 107	reward: 107.0	 ewma reward: 121.45454820761086
# Episode 608	length: 106	reward: 106.0	 ewma reward: 120.6818207972303
# Episode 609	length: 112	reward: 112.0	 ewma reward: 120.24772975736877
# Episode 610	length: 27	reward: 27.0	 ewma reward: 115.58534326950033
# Episode 611	length: 113	reward: 113.0	 ewma reward: 115.45607610602531
# Episode 612	length: 100	reward: 100.0	 ewma reward: 114.68327230072404
# Episode 613	length: 103	reward: 103.0	 ewma reward: 114.09910868568784
# Episode 614	length: 107	reward: 107.0	 ewma reward: 113.74415325140343
# Episode 615	length: 104	reward: 104.0	 ewma reward: 113.25694558883326
# Episode 616	length: 103	reward: 103.0	 ewma reward: 112.7440983093916
# Episode 617	length: 39	reward: 39.0	 ewma reward: 109.05689339392202
# Episode 618	length: 29	reward: 29.0	 ewma reward: 105.05404872422592
# Episode 619	length: 29	reward: 29.0	 ewma reward: 101.25134628801463
# Episode 620	length: 17	reward: 17.0	 ewma reward: 97.03877897361389
# Episode 621	length: 106	reward: 106.0	 ewma reward: 97.48684002493319
# Episode 622	length: 116	reward: 116.0	 ewma reward: 98.41249802368652
# Episode 623	length: 105	reward: 105.0	 ewma reward: 98.7418731225022
# Episode 624	length: 109	reward: 109.0	 ewma reward: 99.25477946637709
# Episode 625	length: 111	reward: 111.0	 ewma reward: 99.84204049305822
# Episode 626	length: 116	reward: 116.0	 ewma reward: 100.6499384684053
# Episode 627	length: 105	reward: 105.0	 ewma reward: 100.86744154498503
# Episode 670	length: 94	reward: 94.0	 ewma reward: 70.21881167311675
# Episode 671	length: 72	reward: 72.0	 ewma reward: 70.3078710894609
# Episode 672	length: 100	reward: 100.0	 ewma reward: 71.79247753498785
# Episode 673	length: 71	reward: 71.0	 ewma reward: 71.75285365823845
# Episode 674	length: 75	reward: 75.0	 ewma reward: 71.91521097532653
# Episode 675	length: 81	reward: 81.0	 ewma reward: 72.36945042656019
# Episode 676	length: 65	reward: 65.0	 ewma reward: 72.00097790523218
# Episode 677	length: 71	reward: 71.0	 ewma reward: 71.95092900997057
# Episode 678	length: 64	reward: 64.0	 ewma reward: 71.55338255947204
# Episode 679	length: 66	reward: 66.0	 ewma reward: 71.27571343149843
# Episode 680	length: 17	reward: 17.0	 ewma reward: 68.5619277599235
# Episode 681	length: 53	reward: 53.0	 ewma reward: 67.78383137192733
# Episode 682	length: 65	reward: 65.0	 ewma reward: 67.64463980333096
# Episode 683	length: 72	reward: 72.0	 ewma reward: 67.86240781316441
# Episode 684	length: 85	reward: 85.0	 ewma reward: 68.71928742250618
# Episode 685	length: 72	reward: 72.0	 ewma reward: 68.88332305138087
# Episode 686	length: 61	reward: 61.0	 ewma reward: 68.48915689881181
# Episode 687	length: 71	reward: 71.0	 ewma reward: 68.61469905387122
# Episode 688	length: 79	reward: 79.0	 ewma reward: 69.13396410117765
# Episode 689	length: 81	reward: 81.0	 ewma reward: 69.72726589611877
# Episode 690	length: 98	reward: 98.0	 ewma reward: 71.14090260131283
# Episode 691	length: 107	reward: 107.0	 ewma reward: 72.93385747124718
# ...
# Episode 2039	length: 200	reward: 200.0	 ewma reward: 179.9998789802167
# Episode 2040	length: 200	reward: 200.0	 ewma reward: 180.99988503120585
# Episode 2041	length: 200	reward: 200.0	 ewma reward: 181.94989077964556
# Episode 2042	length: 200	reward: 200.0	 ewma reward: 182.85239624066327
# Episode 2043	length: 200	reward: 200.0	 ewma reward: 183.7097764286301
# Episode 2044	length: 200	reward: 200.0	 ewma reward: 184.5242876071986
# Episode 2045	length: 195	reward: 195.0	 ewma reward: 185.04807322683865
# Episode 2046	length: 200	reward: 200.0	 ewma reward: 185.79566956549672
# Episode 2047	length: 200	reward: 200.0	 ewma reward: 186.50588608722188
# Episode 2048	length: 148	reward: 148.0	 ewma reward: 184.58059178286078
# Episode 2049	length: 93	reward: 93.0	 ewma reward: 180.00156219371775
# Episode 2050	length: 75	reward: 75.0	 ewma reward: 174.75148408403186
# Episode 2051	length: 108	reward: 108.0	 ewma reward: 171.41390987983027
# Episode 2052	length: 64	reward: 64.0	 ewma reward: 166.04321438583875
# Episode 2053	length: 76	reward: 76.0	 ewma reward: 161.54105366654682
# Episode 2054	length: 84	reward: 84.0	 ewma reward: 157.66400098321947
# Episode 2055	length: 52	reward: 52.0	 ewma reward: 152.38080093405847
# Episode 2056	length: 68	reward: 68.0	 ewma reward: 148.16176088735554
# Episode 2057	length: 65	reward: 65.0	 ewma reward: 144.00367284298775
# Episode 2058	length: 117	reward: 117.0	 ewma reward: 142.65348920083835
# Episode 2059	length: 61	reward: 61.0	 ewma reward: 138.57081474079644
# Episode 2060	length: 77	reward: 77.0	 ewma reward: 135.4922740037566
# Episode 2061	length: 77	reward: 77.0	 ewma reward: 132.56766030356874
# Episode 2062	length: 89	reward: 89.0	 ewma reward: 130.3892772883903
# Episode 2063	length: 67	reward: 67.0	 ewma reward: 127.21981342397078
# Episode 2064	length: 79	reward: 79.0	 ewma reward: 124.80882275277223
# Episode 2065	length: 59	reward: 59.0	 ewma reward: 121.51838161513362
# Episode 2066	length: 63	reward: 63.0	 ewma reward: 118.59246253437693
# Episode 2067	length: 137	reward: 137.0	 ewma reward: 119.51283940765808
# Episode 2068	length: 78	reward: 78.0	 ewma reward: 117.43719743727517
# Episode 2069	length: 66	reward: 66.0	 ewma reward: 114.86533756541141
# Episode 2070	length: 91	reward: 91.0	 ewma reward: 113.67207068714083
# Episode 2071	length: 52	reward: 52.0	 ewma reward: 110.58846715278378
# Episode 2072	length: 58	reward: 58.0	 ewma reward: 107.9590437951446
# Episode 2073	length: 43	reward: 43.0	 ewma reward: 104.71109160538737
# Episode 2074	length: 75	reward: 75.0	 ewma reward: 103.22553702511799
# Episode 2075	length: 101	reward: 101.0	 ewma reward: 103.11426017386208
# Episode 2076	length: 70	reward: 70.0	 ewma reward: 101.45854716516897
# Episode 2077	length: 62	reward: 62.0	 ewma reward: 99.4856198069105
# Episode 2078	length: 92	reward: 92.0	 ewma reward: 99.11133881656497
# Episode 2079	length: 82	reward: 82.0	 ewma reward: 98.25577187573671
# Episode 2080	length: 98	reward: 98.0	 ewma reward: 98.24298328194988
# Episode 2081	length: 143	reward: 143.0	 ewma reward: 100.48083411785238
# Episode 2082	length: 125	reward: 125.0	 ewma reward: 101.70679241195975
# Episode 2083	length: 68	reward: 68.0	 ewma reward: 100.02145279136177
# Episode 2084	length: 145	reward: 145.0	 ewma reward: 102.27038015179367
# Episode 2085	length: 68	reward: 68.0	 ewma reward: 100.55686114420399
# Episode 2086	length: 200	reward: 200.0	 ewma reward: 105.52901808699379
# Episode 2087	length: 107	reward: 107.0	 ewma reward: 105.6025671826441
# Episode 2088	length: 124	reward: 124.0	 ewma reward: 106.52243882351189
# Episode 2089	length: 92	reward: 92.0	 ewma reward: 105.79631688233628
# Episode 2090	length: 188	reward: 188.0	 ewma reward: 109.90650103821947
# Episode 2091	length: 74	reward: 74.0	 ewma reward: 108.1111759863085
# Episode 2092	length: 200	reward: 200.0	 ewma reward: 112.70561718699307
# Episode 2093	length: 200	reward: 200.0	 ewma reward: 117.0703363276434
# Episode 2094	length: 200	reward: 200.0	 ewma reward: 121.21681951126122
# Episode 2095	length: 200	reward: 200.0	 ewma reward: 125.15597853569815
# Episode 2096	length: 200	reward: 200.0	 ewma reward: 128.89817960891324
# Episode 2097	length: 200	reward: 200.0	 ewma reward: 132.45327062846758
# Episode 2098	length: 104	reward: 104.0	 ewma reward: 131.0306070970442
# Episode 2099	length: 118	reward: 118.0	 ewma reward: 130.37907674219198
# Episode 2100	length: 200	reward: 200.0	 ewma reward: 133.8601229050824
# Episode 2101	length: 200	reward: 200.0	 ewma reward: 137.16711675982828
# Episode 2102	length: 72	reward: 72.0	 ewma reward: 133.90876092183686
# Episode 2103	length: 51	reward: 51.0	 ewma reward: 129.76332287574502
# Episode 2104	length: 200	reward: 200.0	 ewma reward: 133.27515673195776
# Episode 2105	length: 200	reward: 200.0	 ewma reward: 136.61139889535986
# Episode 2106	length: 191	reward: 191.0	 ewma reward: 139.33082895059187
# Episode 2107	length: 200	reward: 200.0	 ewma reward: 142.36428750306226
# Episode 2108	length: 64	reward: 64.0	 ewma reward: 138.44607312790913
# Episode 2109	length: 166	reward: 166.0	 ewma reward: 139.82376947151369
# Episode 2110	length: 167	reward: 167.0	 ewma reward: 141.18258099793798
# Episode 2111	length: 48	reward: 48.0	 ewma reward: 136.52345194804107
# Episode 2112	length: 158	reward: 158.0	 ewma reward: 137.597279350639
# Episode 2113	length: 40	reward: 40.0	 ewma reward: 132.71741538310707
# Episode 2114	length: 105	reward: 105.0	 ewma reward: 131.3315446139517
# Episode 2115	length: 144	reward: 144.0	 ewma reward: 131.9649673832541
# Episode 2116	length: 20	reward: 20.0	 ewma reward: 126.36671901409139
# Episode 2117	length: 12	reward: 12.0	 ewma reward: 120.6483830633868
# Episode 2118	length: 144	reward: 144.0	 ewma reward: 121.81596391021746
# Episode 2119	length: 12	reward: 12.0	 ewma reward: 116.32516571470657
# Episode 2120	length: 14	reward: 14.0	 ewma reward: 111.20890742897124
# Episode 2121	length: 13	reward: 13.0	 ewma reward: 106.29846205752268
# Episode 2122	length: 131	reward: 131.0	 ewma reward: 107.53353895464654
# Episode 2123	length: 16	reward: 16.0	 ewma reward: 102.9568620069142
# Episode 2124	length: 19	reward: 19.0	 ewma reward: 98.7590189065685
# Episode 2125	length: 16	reward: 16.0	 ewma reward: 94.62106796124007
# Episode 2126	length: 12	reward: 12.0	 ewma reward: 90.49001456317806
# Episode 2127	length: 134	reward: 134.0	 ewma reward: 92.66551383501915
# Episode 2128	length: 16	reward: 16.0	 ewma reward: 88.83223814326819
# Episode 2129	length: 129	reward: 129.0	 ewma reward: 90.84062623610477
# Episode 2130	length: 127	reward: 127.0	 ewma reward: 92.64859492429952
# Episode 2131	length: 14	reward: 14.0	 ewma reward: 88.71616517808454
# Episode 2132	length: 138	reward: 138.0	 ewma reward: 91.18035691918031
# Episode 2133	length: 18	reward: 18.0	 ewma reward: 87.5213390732213
# Episode 2134	length: 138	reward: 138.0	 ewma reward: 90.04527211956024
# Episode 2135	length: 137	reward: 137.0	 ewma reward: 92.39300851358222
# Episode 2136	length: 137	reward: 137.0	 ewma reward: 94.6233580879031
# Episode 2137	length: 21	reward: 21.0	 ewma reward: 90.94219018350793
# Episode 2138	length: 134	reward: 134.0	 ewma reward: 93.09508067433254
# Episode 2139	length: 114	reward: 114.0	 ewma reward: 94.14032664061591
# Episode 2140	length: 16	reward: 16.0	 ewma reward: 90.2333103085851
# Episode 2141	length: 122	reward: 122.0	 ewma reward: 91.82164479315584
# Episode 2142	length: 13	reward: 13.0	 ewma reward: 87.88056255349805
# Episode 2143	length: 14	reward: 14.0	 ewma reward: 84.18653442582315
# Episode 2144	length: 132	reward: 132.0	 ewma reward: 86.57720770453199
# Episode 2145	length: 14	reward: 14.0	 ewma reward: 82.94834731930538
# Episode 2146	length: 25	reward: 25.0	 ewma reward: 80.05092995334012
# Episode 2147	length: 23	reward: 23.0	 ewma reward: 77.19838345567311
# Episode 2148	length: 13	reward: 13.0	 ewma reward: 73.98846428288945
# Episode 2149	length: 14	reward: 14.0	 ewma reward: 70.98904106874498
# Episode 2150	length: 17	reward: 17.0	 ewma reward: 68.28958901530773
# Episode 2151	length: 133	reward: 133.0	 ewma reward: 71.52510956454235
# Episode 2152	length: 132	reward: 132.0	 ewma reward: 74.54885408631522
# Episode 2153	length: 14	reward: 14.0	 ewma reward: 71.52141138199946
# Episode 2154	length: 120	reward: 120.0	 ewma reward: 73.94534081289947
# Episode 2155	length: 124	reward: 124.0	 ewma reward: 76.4480737722545
# Episode 2156	length: 122	reward: 122.0	 ewma reward: 78.72567008364177
# Episode 2157	length: 125	reward: 125.0	 ewma reward: 81.03938657945969
# Episode 2158	length: 120	reward: 120.0	 ewma reward: 82.9874172504867
# Episode 2159	length: 136	reward: 136.0	 ewma reward: 85.63804638796236
# Episode 2160	length: 137	reward: 137.0	 ewma reward: 88.20614406856423
# Episode 2161	length: 130	reward: 130.0	 ewma reward: 90.29583686513601
# Episode 2162	length: 154	reward: 154.0	 ewma reward: 93.48104502187921
# Episode 2163	length: 151	reward: 151.0	 ewma reward: 96.35699277078524
# Episode 2164	length: 68	reward: 68.0	 ewma reward: 94.93914313224597
# Episode 2165	length: 61	reward: 61.0	 ewma reward: 93.24218597563367
# Episode 2166	length: 161	reward: 161.0	 ewma reward: 96.63007667685198
# Episode 2167	length: 200	reward: 200.0	 ewma reward: 101.79857284300938
# Episode 2168	length: 193	reward: 193.0	 ewma reward: 106.35864420085892
# Episode 2169	length: 165	reward: 165.0	 ewma reward: 109.29071199081596
# Episode 2170	length: 171	reward: 171.0	 ewma reward: 112.37617639127515
# Episode 2171	length: 55	reward: 55.0	 ewma reward: 109.50736757171138
# Episode 2172	length: 121	reward: 121.0	 ewma reward: 110.08199919312581
# Episode 2173	length: 191	reward: 191.0	 ewma reward: 114.1278992334695
# Episode 2174	length: 126	reward: 126.0	 ewma reward: 114.72150427179602
# Episode 2175	length: 92	reward: 92.0	 ewma reward: 113.58542905820622
# Episode 2176	length: 121	reward: 121.0	 ewma reward: 113.9561576052959
# Episode 2177	length: 136	reward: 136.0	 ewma reward: 115.05834972503109
# Episode 2178	length: 44	reward: 44.0	 ewma reward: 111.50543223877953
# Episode 2179	length: 200	reward: 200.0	 ewma reward: 115.93016062684055
# Episode 2180	length: 67	reward: 67.0	 ewma reward: 113.48365259549851
# Episode 2181	length: 200	reward: 200.0	 ewma reward: 117.80946996572358
# Episode 2182	length: 200	reward: 200.0	 ewma reward: 121.9189964674374
# Episode 2183	length: 140	reward: 140.0	 ewma reward: 122.82304664406551
# Episode 2184	length: 200	reward: 200.0	 ewma reward: 126.68189431186224
# Episode 2185	length: 200	reward: 200.0	 ewma reward: 130.3477995962691
# Episode 2186	length: 106	reward: 106.0	 ewma reward: 129.13040961645567
# Episode 2187	length: 112	reward: 112.0	 ewma reward: 128.27388913563288
# Episode 2188	length: 200	reward: 200.0	 ewma reward: 131.86019467885123
# Episode 2189	length: 200	reward: 200.0	 ewma reward: 135.26718494490865
# Episode 2190	length: 200	reward: 200.0	 ewma reward: 138.50382569766322
# Episode 2191	length: 200	reward: 200.0	 ewma reward: 141.57863441278005
# Episode 2192	length: 200	reward: 200.0	 ewma reward: 144.49970269214103
# Episode 2193	length: 37	reward: 37.0	 ewma reward: 139.12471755753396
# Episode 2194	length: 85	reward: 85.0	 ewma reward: 136.41848167965725
# Episode 2195	length: 200	reward: 200.0	 ewma reward: 139.59755759567437
# Episode 2196	length: 77	reward: 77.0	 ewma reward: 136.46767971589065
# Episode 2197	length: 200	reward: 200.0	 ewma reward: 139.6442957300961
# Episode 2198	length: 131	reward: 131.0	 ewma reward: 139.2120809435913
# Episode 2199	length: 200	reward: 200.0	 ewma reward: 142.25147689641173
# Episode 2200	length: 190	reward: 190.0	 ewma reward: 144.63890305159114
# Episode 2201	length: 200	reward: 200.0	 ewma reward: 147.4069578990116
# Episode 2202	length: 200	reward: 200.0	 ewma reward: 150.036610004061
# Episode 2203	length: 195	reward: 195.0	 ewma reward: 152.28477950385795
# Episode 2204	length: 186	reward: 186.0	 ewma reward: 153.97054052866505
# Episode 2205	length: 193	reward: 193.0	 ewma reward: 155.9220135022318
# Episode 2206	length: 183	reward: 183.0	 ewma reward: 157.2759128271202
# Episode 2207	length: 130	reward: 130.0	 ewma reward: 155.9121171857642
# Episode 2208	length: 200	reward: 200.0	 ewma reward: 158.11651132647597
# Episode 2209	length: 192	reward: 192.0	 ewma reward: 159.81068576015215
# Episode 2210	length: 200	reward: 200.0	 ewma reward: 161.82015147214454
# Episode 2211	length: 174	reward: 174.0	 ewma reward: 162.4291438985373
# Episode 2212	length: 200	reward: 200.0	 ewma reward: 164.30768670361041
# Episode 2213	length: 200	reward: 200.0	 ewma reward: 166.0923023684299
# Episode 2214	length: 200	reward: 200.0	 ewma reward: 167.7876872500084
# Episode 2215	length: 200	reward: 200.0	 ewma reward: 169.39830288750795
# Episode 2216	length: 86	reward: 86.0	 ewma reward: 165.22838774313257
# Episode 2217	length: 200	reward: 200.0	 ewma reward: 166.96696835597592
# Episode 2218	length: 85	reward: 85.0	 ewma reward: 162.86861993817712
# Episode 2219	length: 200	reward: 200.0	 ewma reward: 164.72518894126824
# Episode 2220	length: 200	reward: 200.0	 ewma reward: 166.48892949420483
# Episode 2221	length: 200	reward: 200.0	 ewma reward: 168.16448301949458
# Episode 2222	length: 200	reward: 200.0	 ewma reward: 169.75625886851984
# Episode 2223	length: 200	reward: 200.0	 ewma reward: 171.26844592509383
# Episode 2224	length: 200	reward: 200.0	 ewma reward: 172.70502362883914
# Episode 2225	length: 200	reward: 200.0	 ewma reward: 174.06977244739718
# Episode 2226	length: 200	reward: 200.0	 ewma reward: 175.36628382502732
# Episode 2227	length: 200	reward: 200.0	 ewma reward: 176.59796963377596
# Episode 2228	length: 200	reward: 200.0	 ewma reward: 177.76807115208715
# Episode 2229	length: 200	reward: 200.0	 ewma reward: 178.87966759448278
# Episode 2230	length: 200	reward: 200.0	 ewma reward: 179.93568421475862
# Episode 2231	length: 200	reward: 200.0	 ewma reward: 180.9389000040207
# Episode 2232	length: 200	reward: 200.0	 ewma reward: 181.89195500381965
# Episode 2233	length: 200	reward: 200.0	 ewma reward: 182.79735725362866
# Episode 2234	length: 200	reward: 200.0	 ewma reward: 183.65748939094723
# Episode 2235	length: 200	reward: 200.0	 ewma reward: 184.47461492139988
# Episode 2236	length: 200	reward: 200.0	 ewma reward: 185.25088417532987
# Episode 2237	length: 200	reward: 200.0	 ewma reward: 185.98833996656336
# Episode 2238	length: 200	reward: 200.0	 ewma reward: 186.68892296823518
# Episode 2239	length: 200	reward: 200.0	 ewma reward: 187.35447681982342
# Episode 2240	length: 200	reward: 200.0	 ewma reward: 187.98675297883224
# Episode 2241	length: 200	reward: 200.0	 ewma reward: 188.58741532989063
# Episode 2242	length: 200	reward: 200.0	 ewma reward: 189.1580445633961
# Episode 2243	length: 200	reward: 200.0	 ewma reward: 189.70014233522627
# Episode 2244	length: 200	reward: 200.0	 ewma reward: 190.21513521846495
# Episode 2245	length: 200	reward: 200.0	 ewma reward: 190.7043784575417
# Episode 2246	length: 200	reward: 200.0	 ewma reward: 191.1691595346646
# Episode 2247	length: 200	reward: 200.0	 ewma reward: 191.61070155793135
# Episode 2248	length: 200	reward: 200.0	 ewma reward: 192.03016648003478
# Episode 2249	length: 200	reward: 200.0	 ewma reward: 192.42865815603304
# Episode 2250	length: 200	reward: 200.0	 ewma reward: 192.8072252482314
# Episode 2251	length: 200	reward: 200.0	 ewma reward: 193.16686398581982
# Episode 2252	length: 200	reward: 200.0	 ewma reward: 193.5085207865288
# Episode 2253	length: 200	reward: 200.0	 ewma reward: 193.83309474720235
# Episode 2254	length: 200	reward: 200.0	 ewma reward: 194.14144000984223
# Episode 2255	length: 200	reward: 200.0	 ewma reward: 194.4343680093501
# Episode 2256	length: 200	reward: 200.0	 ewma reward: 194.71264960888257
# Episode 2257	length: 200	reward: 200.0	 ewma reward: 194.97701712843843
# Episode 2258	length: 200	reward: 200.0	 ewma reward: 195.2281662720165
# Solved! Running reward is now 195.2281662720165 and the last episode runs to 200 time steps!
# Episode 1	Reward: 200.0
# Episode 2	Reward: 200.0
# Episode 3	Reward: 18.0
# Episode 4	Reward: 200.0
# Episode 5	Reward: 17.0
# Episode 6	Reward: 200.0
# Episode 7	Reward: 200.0
# Episode 8	Reward: 200.0
# Episode 9	Reward: 200.0
# Episode 10	Reward: 200.0
